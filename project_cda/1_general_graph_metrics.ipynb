# %% [markdown]
# # **General Network Evolution Analysis: Anime and User Graphs (2006–2018)**

# %% [markdown]
# # **1. Overview**
#
# This notebook conducts analysis of the evolution of the community from 2006 to 2018. We examine two distinct network topologies to understand how the ecosystem has matured over time:
#
# The Anime Graph: Represents the relationships between anime titles (nodes). Edges represent similarities, recommendations, or co-occurrence. Graph is weighted, weights are represented as user votes for anime
#
# The User Graph: Represents the social structure of the community. Edges represent interactions (votes) or shared interests between users. Graph is weighted, weights are represented as strenght of the connection between users vited the same anime

# %% [markdown]
# Necessary imports:

# %%
import os
import igraph as ig
import numpy as np
from pathlib import Path
from dotenv import load_dotenv

# Import your custom modules
from graph_metrics import GraphMetricsIG
from graph_actions_ig import GraphActionsIG
from graph_io import GraphIO

# 1. Load Environment Variables
load_dotenv(override=True)

# 2. Get the directories from .env
# We use Path() here so we can easily add filenames later with the / operator
ANIME_GRAPHS_DIR = Path(os.getenv("ANIME_GRAPHS_DIR"))
USER_GRAPHS_DIR = Path(os.getenv("USER_GRAPHS_DIR"))

# 3. Define Anime Paths (Using .env directory)
anime_jacth005_2006_pkl = str(ANIME_GRAPHS_DIR / "2006.pkl")
anime_jacth005_2007_pkl = str(ANIME_GRAPHS_DIR / "2007.pkl")
anime_jacth005_2008_pkl = str(ANIME_GRAPHS_DIR / "2008.pkl")
anime_jacth005_2009_pkl = str(ANIME_GRAPHS_DIR / "2009.pkl")
anime_jacth005_2010_pkl = str(ANIME_GRAPHS_DIR / "2010.pkl")
anime_jacth005_2011_pkl = str(ANIME_GRAPHS_DIR / "2011.pkl")
anime_jacth005_2012_pkl = str(ANIME_GRAPHS_DIR / "2012.pkl")
anime_jacth005_2013_pkl = str(ANIME_GRAPHS_DIR / "2013.pkl")
anime_jacth005_2014_pkl = str(ANIME_GRAPHS_DIR / "2014.pkl")
anime_jacth005_2015_pkl = str(ANIME_GRAPHS_DIR / "2015.pkl")
anime_jacth005_2016_pkl = str(ANIME_GRAPHS_DIR / "2016.pkl")
anime_jacth005_2017_pkl = str(ANIME_GRAPHS_DIR / "2017.pkl")
anime_jacth005_2018_pkl = str(ANIME_GRAPHS_DIR / "2018.pkl")

# 4. Define User Paths (Using .env directory)
user_raw_2006_pkl = str(USER_GRAPHS_DIR / "raw" / "user_graph_2006_thr_3_q_low5_cut_1900.gpickle")
user_raw_2007_pkl = str(USER_GRAPHS_DIR / "raw" / "user_graph_2007_thr_3_q_low5_cut_1900.gpickle")
user_raw_2008_pkl = str(USER_GRAPHS_DIR / "raw" / "user_graph_2008_thr_3_q_low5_cut_1900.gpickle")
user_raw_2009_pkl = str(USER_GRAPHS_DIR / "raw" / "user_graph_2009_thr_3_q_low5_cut_1900.gpickle")
user_raw_2010_pkl = str(USER_GRAPHS_DIR / "raw" / "user_graph_2010_thr_3_q_low5_cut_1900.gpickle")
user_raw_2011_pkl = str(USER_GRAPHS_DIR / "raw" / "user_graph_2011_thr_3_q_low5_cut_1900.gpickle")
user_raw_2012_pkl = str(USER_GRAPHS_DIR / "raw" / "user_graph_2012_thr_3_q_low5_cut_1900.gpickle")
user_raw_2013_pkl = str(USER_GRAPHS_DIR / "raw" / "user_graph_2013_thr_3_q_low5_cut_1900.gpickle")
user_raw_2014_pkl = str(USER_GRAPHS_DIR / "raw" / "user_graph_2014_thr_3_q_low5_cut_1900.gpickle")
user_raw_2015_pkl = str(USER_GRAPHS_DIR / "raw" / "user_graph_2015_thr_3_q_low5_cut_1900.gpickle")
user_raw_2016_pkl = str(USER_GRAPHS_DIR / "raw" / "user_graph_2016_thr_3_q_low5_cut_1900.gpickle")
user_raw_2017_pkl = str(USER_GRAPHS_DIR / "raw" / "user_graph_2017_thr_3_q_low5_cut_1900.gpickle")
user_raw_2018_pkl = str(USER_GRAPHS_DIR / "raw" / "user_graph_2018_thr_3_q_low5_cut_1900.gpickle")

# 5. Build Dictionaries
graph_paths_anime = {
    2006: anime_jacth005_2006_pkl,
    2007: anime_jacth005_2007_pkl,
    2008: anime_jacth005_2008_pkl,
    2009: anime_jacth005_2009_pkl,
    2010: anime_jacth005_2010_pkl,
    2011: anime_jacth005_2011_pkl,
    2012: anime_jacth005_2012_pkl,
    2013: anime_jacth005_2013_pkl,
    2014: anime_jacth005_2014_pkl,
    2015: anime_jacth005_2015_pkl,
    2016: anime_jacth005_2016_pkl,
    2017: anime_jacth005_2017_pkl,
    2018: anime_jacth005_2018_pkl
}

graph_paths_users = {
    2006: user_raw_2006_pkl,
    2007: user_raw_2007_pkl,
    2008: user_raw_2008_pkl,
    2009: user_raw_2009_pkl,
    2010: user_raw_2010_pkl,
    2011: user_raw_2011_pkl,
    2012: user_raw_2012_pkl,
    2013: user_raw_2013_pkl,
    2014: user_raw_2014_pkl,
    2015: user_raw_2015_pkl,
    2016: user_raw_2016_pkl,
    2017: user_raw_2017_pkl,
    2018: user_raw_2018_pkl
}

# %% [markdown]
# # **2. Anime Graph Metrics Analysis (2006–2018)**
#
# In this section, we generate the full metric reports for the Anime networks. For each year from 2006 to 2018, following metrics are calculated to track the evolution:
#
# **Network Size & Connectivity**
# * **Nodes & Edges:** Total count of anime titles and their similarity connections.
# * **Density:** The ratio of actual connections to potential connections.
# * **Connected Components:** The number of isolated groups within the network.
# * **LCC Size:** The size of the Largest Connected Component.
#
# **Path & Distance Metrics (Weighted)**
# * **Weighted Diameter:** The longest shortest path (distance-based).
# * **Avg Path Length:** The average number of steps to reach any anime from another (in the LCC).
#
# **Centrality & Influence**
# * **Average Degree & Std:** The average connectivity (popularity) and its variance.
# * **Mean Closeness:** How fast a node can access all other nodes.
# * **Mean Betweenness:** How often a node acts as a bridge between groups.
# * **Mean Eigenvector:** Measure of influence based on connections to other highly connected nodes.
#
# **Cohesion & Clustering**
# * **Clustering Coefficient:** The tendency of nodes to form tight local groups ("bubbles").
# * **Transitivity:** The global probability of triangles forming in the graph.
# * **Core Number (Mean & Max):** A measure of how deep nodes are embedded in the network (finding the "mainstream" core).
# * **Assortativity:** The correlation between linked nodes (do popular anime link to other popular anime?).

# %%
print("--- Starting Manual Analysis for Anime Graphs (2006-2018) ---\n")

# 2006
print(">>> Processing 2006...")
GraphMetricsIG.print_anime_graph_metrics(
    GraphMetricsIG.get_full_metrics_dict(
        GraphActionsIG.get_graph(anime_jacth005_2006_pkl), 
        "anime_jacth005_2006_pkl"
    )
)

# 2007
print("\n>>> Processing 2007...")
GraphMetricsIG.print_anime_graph_metrics(
    GraphMetricsIG.get_full_metrics_dict(
        GraphActionsIG.get_graph(anime_jacth005_2007_pkl), 
        "anime_jacth005_2007_pkl"
    )
)

# 2008
print("\n>>> Processing 2008...")
GraphMetricsIG.print_anime_graph_metrics(
    GraphMetricsIG.get_full_metrics_dict(
        GraphActionsIG.get_graph(anime_jacth005_2008_pkl), 
        "anime_jacth005_2008_pkl"
    )
)

# 2009
print("\n>>> Processing 2009...")
GraphMetricsIG.print_anime_graph_metrics(
    GraphMetricsIG.get_full_metrics_dict(
        GraphActionsIG.get_graph(anime_jacth005_2009_pkl), 
        "anime_jacth005_2009_pkl"
    )
)

# 2010
print("\n>>> Processing 2010...")
GraphMetricsIG.print_anime_graph_metrics(
    GraphMetricsIG.get_full_metrics_dict(
        GraphActionsIG.get_graph(anime_jacth005_2010_pkl), 
        "anime_jacth005_2010_pkl"
    )
)

# 2011
print("\n>>> Processing 2011...")
GraphMetricsIG.print_anime_graph_metrics(
    GraphMetricsIG.get_full_metrics_dict(
        GraphActionsIG.get_graph(anime_jacth005_2011_pkl), 
        "anime_jacth005_2011_pkl"
    )
)

# 2012
print("\n>>> Processing 2012...")
GraphMetricsIG.print_anime_graph_metrics(
    GraphMetricsIG.get_full_metrics_dict(
        GraphActionsIG.get_graph(anime_jacth005_2012_pkl), 
        "anime_jacth005_2012_pkl"
    )
)

# 2013
print("\n>>> Processing 2013...")
GraphMetricsIG.print_anime_graph_metrics(
    GraphMetricsIG.get_full_metrics_dict(
        GraphActionsIG.get_graph(anime_jacth005_2013_pkl), 
        "anime_jacth005_2013_pkl"
    )
)

# 2014
print("\n>>> Processing 2014...")
GraphMetricsIG.print_anime_graph_metrics(
    GraphMetricsIG.get_full_metrics_dict(
        GraphActionsIG.get_graph(anime_jacth005_2014_pkl), 
        "anime_jacth005_2014_pkl"
    )
)

# 2015
print("\n>>> Processing 2015...")
GraphMetricsIG.print_anime_graph_metrics(
    GraphMetricsIG.get_full_metrics_dict(
        GraphActionsIG.get_graph(anime_jacth005_2015_pkl), 
        "anime_jacth005_2015_pkl"
    )
)

# 2016
print("\n>>> Processing 2016...")
GraphMetricsIG.print_anime_graph_metrics(
    GraphMetricsIG.get_full_metrics_dict(
        GraphActionsIG.get_graph(anime_jacth005_2016_pkl), 
        "anime_jacth005_2016_pkl"
    )
)

# 2017
print("\n>>> Processing 2017...")
GraphMetricsIG.print_anime_graph_metrics(
    GraphMetricsIG.get_full_metrics_dict(
        GraphActionsIG.get_graph(anime_jacth005_2017_pkl), 
        "anime_jacth005_2017_pkl"
    )
)

# 2018
print("\n>>> Processing 2018...")
GraphMetricsIG.print_anime_graph_metrics(
    GraphMetricsIG.get_full_metrics_dict(
        GraphActionsIG.get_graph(anime_jacth005_2018_pkl), 
        "anime_jacth005_2018_pkl"
    )
)
# Out:
# --- Starting Manual Analysis for Anime Graphs (2006-2018) ---
#
# >>> Processing 2006...
# Loading file with graph: 2006.pkl...
# Object is iGraph
# Edges: 63857. Weights (min/max): 0.0526 / 1.0000
#
# --- Starting Full Metrics Calculation for anime_jacth005_2006_pkl ---
#   ... Calculating Basic Metrics (Nodes, Edges, Degree)...
#   ... Calculating Path Metrics (Skipping slow ones)...
#       > Diameter (Longest shortest path)...
#       > Average Path Length...
#   ... Calculating Centrality Metrics (Closeness, Betweenness, Eigenvector)...
#       > Closeness Centrality...
#       > Betweenness Centrality (this may take time)...
#       > Eigenvector Centrality...
#   ... Calculating Structural Metrics (Clustering, Transitivity, Coreness)...
# --- Metrics Calculation Complete ---
#
# =============== Analysis Report: anime_jacth005_2006_pkl ===============
# Metric                                   | Value        | Description
# -----------------------------------------------------------------------------------------------
# Number of nodes                          | 732          | Total anime titles
# Number of edges                          | 63857        | Total connections (shared audience)
# Average degree (weighted)                | 35.4435      | Avg connectivity (popularity)
# Degree std (weighted)                    | 19.0764      | Variance in popularity
# Connected components                     | 1            | Isolated groups
# LCC size                                 | 732          | Size of main component
# Weighted diameter - longest shortest path (distance-based) | 29           |
# Weighted radius (distance-based)         | N/A          | Min eccentricity in LCC
# Mean eccentricity (distance-based)       | N/A          | Avg max distance to others
# Avg path length (weighted LCC)           | 7.1006       | Avg steps to reach any anime
# Mean closeness (weighted distance)       | 0.1436       | Access speed to other nodes
# Mean betweenness (weighted distance)     | 0.0633       | Bridge roles (connecting groups/clusters)
# Mean eigenvector (weighted strength)     | 0.2934       | Influence (connected to popular)
# Clustering coefficient mean (weighted)   | 0.7761       | Local cohesion (bubbles)
# Transitivity (weighted)                  | N/A          | Global triangle probability
# Core number mean                         | 108.9098     | Avg depth of embedding
# Max Core number                          | 159          | Deepest 'mainstream' core level
# Assortativity (degree)                   | -0.1077      | Link correlation (-1 to 1)
# Assortativity (strength/weighted)        | 0.1822       | Popularity correlation (-1 to 1)
# Graph Density                            | 0.2387       | Network saturation (0 to 1)
# ===============================================================================================
#
#
# >>> Processing 2007...
# Loading file with graph: 2007.pkl...
# Object is iGraph
# Edges: 180838. Weights (min/max): 0.0500 / 1.0000
# c:\MariaSamosudova\Projects\UNIVER\ADB\Project\MARS_1.0\project_cda\graph_metrics.py:170: RuntimeWarning: Incoming vertex values are ignored when calculating undirected assortativity. Location: src/misc/mixing.c:293
#   assortativity_weighted = g.assortativity(strengths, strengths, directed=False)
# --- Starting Full Metrics Calculation for anime_jacth005_2007_pkl ---
#   ... Calculating Basic Metrics (Nodes, Edges, Degree)...
#   ... Calculating Path Metrics (Skipping slow ones)...
#       > Diameter (Longest shortest path)...
#       > Average Path Length...
#   ... Calculating Centrality Metrics (Closeness, Betweenness, Eigenvector)...
#       > Closeness Centrality...
#       > Betweenness Centrality (this may take time)...
#       > Eigenvector Centrality...
#   ... Calculating Structural Metrics (Clustering, Transitivity, Coreness)...
# --- Metrics Calculation Complete ---
#
# =============== Analysis Report: anime_jacth005_2007_pkl ===============
# Metric                                   | Value        | Description
# -----------------------------------------------------------------------------------------------
# Number of nodes                          | 1837         | Total anime titles
# Number of edges                          | 180838       | Total connections (shared audience)
# Average degree (weighted)                | 16.9876      | Avg connectivity (popularity)
# Degree std (weighted)                    | 16.1173      | Variance in popularity
# Connected components                     | 2            | Isolated groups
# LCC size                                 | 1835         | Size of main component
# Weighted diameter - longest shortest path (distance-based) | 74.6667      |
# Weighted radius (distance-based)         | N/A          | Min eccentricity in LCC
# Mean eccentricity (distance-based)       | N/A          | Avg max distance to others
# Avg path length (weighted LCC)           | 24.7586      | Avg steps to reach any anime
# Mean closeness (weighted distance)       | 0.0420       | Access speed to other nodes
# Mean betweenness (weighted distance)     | 0.0005       | Bridge roles (connecting groups/clusters)
# Mean eigenvector (weighted strength)     | 0.1696       | Influence (connected to popular)
# Clustering coefficient mean (weighted)   | 0.5063       | Local cohesion (bubbles)
# Transitivity (weighted)                  | N/A          | Global triangle probability
# Core number mean                         | 119.0474     | Avg depth of embedding
# Max Core number                          | 260          | Deepest 'mainstream' core level
# Assortativity (degree)                   | 0.5665       | Link correlation (-1 to 1)
# Assortativity (strength/weighted)        | 0.4873       | Popularity correlation (-1 to 1)
# Graph Density                            | 0.1072       | Network saturation (0 to 1)
# ===============================================================================================
#
#
# >>> Processing 2008...
# Loading file with graph: 2008.pkl...
# Object is iGraph
# Edges: 179075. Weights (min/max): 0.0500 / 1.0000
#
# --- Starting Full Metrics Calculation for anime_jacth005_2008_pkl ---
#   ... Calculating Basic Metrics (Nodes, Edges, Degree)...
#   ... Calculating Path Metrics (Skipping slow ones)...
#       > Diameter (Longest shortest path)...
# c:\MariaSamosudova\Projects\UNIVER\ADB\Project\MARS_1.0\project_cda\graph_metrics.py:123: RuntimeWarning: Some eigenvector centralities are nearly zero, indicating that the graph may not be (strongly) connected. Eigenvector centrality is not meaningful for disconnected graphs. Location: src/centrality/eigenvector.c:103
#   eig = g.eigenvector_centrality(weights="weight", scale=True)
#       > Average Path Length...
#   ... Calculating Centrality Metrics (Closeness, Betweenness, Eigenvector)...
#       > Closeness Centrality...
#       > Betweenness Centrality (this may take time)...
#       > Eigenvector Centrality...
#   ... Calculating Structural Metrics (Clustering, Transitivity, Coreness)...
# --- Metrics Calculation Complete ---
#
# =============== Analysis Report: anime_jacth005_2008_pkl ===============
# Metric                                   | Value        | Description
# -----------------------------------------------------------------------------------------------
# Number of nodes                          | 2294         | Total anime titles
# Number of edges                          | 179075       | Total connections (shared audience)
# Average degree (weighted)                | 13.4074      | Avg connectivity (popularity)
# Degree std (weighted)                    | 17.0554      | Variance in popularity
# Connected components                     | 1            | Isolated groups
# LCC size                                 | 2294         | Size of main component
# Weighted diameter - longest shortest path (distance-based) | 103.3351     |
# Weighted radius (distance-based)         | N/A          | Min eccentricity in LCC
# Mean eccentricity (distance-based)       | N/A          | Avg max distance to others
# Avg path length (weighted LCC)           | 35.6649      | Avg steps to reach any anime
# Mean closeness (weighted distance)       | 0.0288       | Access speed to other nodes
# Mean betweenness (weighted distance)     | 0            | Bridge roles (connecting groups/clusters)
# Mean eigenvector (weighted strength)     | 0.1394       | Influence (connected to popular)
# Clustering coefficient mean (weighted)   | 0.5416       | Local cohesion (bubbles)
# Transitivity (weighted)                  | N/A          | Global triangle probability
# Core number mean                         | 96.9821      | Avg depth of embedding
# Max Core number                          | 284          | Deepest 'mainstream' core level
# Assortativity (degree)                   | 0.5514       | Link correlation (-1 to 1)
# Assortativity (strength/weighted)        | 0.4506       | Popularity correlation (-1 to 1)
# Graph Density                            | 0.0681       | Network saturation (0 to 1)
# ===============================================================================================
#
#
# >>> Processing 2009...
# Loading file with graph: 2009.pkl...
# Object is iGraph
# Edges: 228793. Weights (min/max): 0.0500 / 1.0000
#
# --- Starting Full Metrics Calculation for anime_jacth005_2009_pkl ---
#   ... Calculating Basic Metrics (Nodes, Edges, Degree)...
#   ... Calculating Path Metrics (Skipping slow ones)...
#       > Diameter (Longest shortest path)...
#       > Average Path Length...
#   ... Calculating Centrality Metrics (Closeness, Betweenness, Eigenvector)...
#       > Closeness Centrality...
#       > Betweenness Centrality (this may take time)...
#       > Eigenvector Centrality...
#   ... Calculating Structural Metrics (Clustering, Transitivity, Coreness)...
# --- Metrics Calculation Complete ---
#
# =============== Analysis Report: anime_jacth005_2009_pkl ===============
# Metric                                   | Value        | Description
# -----------------------------------------------------------------------------------------------
# Number of nodes                          | 2634         | Total anime titles
# Number of edges                          | 228793       | Total connections (shared audience)
# Average degree (weighted)                | 14.9518      | Avg connectivity (popularity)
# Degree std (weighted)                    | 20.1346      | Variance in popularity
# Connected components                     | 8            | Isolated groups
# LCC size                                 | 2617         | Size of main component
# Weighted diameter - longest shortest path (distance-based) | 134.2304     |
# Weighted radius (distance-based)         | N/A          | Min eccentricity in LCC
# Mean eccentricity (distance-based)       | N/A          | Avg max distance to others
# Avg path length (weighted LCC)           | 39.1418      | Avg steps to reach any anime
# Mean closeness (weighted distance)       | 0.0293       | Access speed to other nodes
# Mean betweenness (weighted distance)     | 0            | Bridge roles (connecting groups/clusters)
# Mean eigenvector (weighted strength)     | 0.1387       | Influence (connected to popular)
# Clustering coefficient mean (weighted)   | 0.5693       | Local cohesion (bubbles)
# Transitivity (weighted)                  | N/A          | Global triangle probability
# Core number mean                         | 109.6465     | Avg depth of embedding
# Max Core number                          | 335          | Deepest 'mainstream' core level
# Assortativity (degree)                   | 0.5180       | Link correlation (-1 to 1)
# Assortativity (strength/weighted)        | 0.4091       | Popularity correlation (-1 to 1)
# Graph Density                            | 0.0660       | Network saturation (0 to 1)
# ===============================================================================================
#
#
# >>> Processing 2010...
# Loading file with graph: 2010.pkl...
# Object is iGraph
# Edges: 276701. Weights (min/max): 0.0500 / 1.0000
#
# --- Starting Full Metrics Calculation for anime_jacth005_2010_pkl ---
#   ... Calculating Basic Metrics (Nodes, Edges, Degree)...
#   ... Calculating Path Metrics (Skipping slow ones)...
#       > Diameter (Longest shortest path)...
#       > Average Path Length...
#   ... Calculating Centrality Metrics (Closeness, Betweenness, Eigenvector)...
#       > Closeness Centrality...
#       > Betweenness Centrality (this may take time)...
#       > Eigenvector Centrality...
#   ... Calculating Structural Metrics (Clustering, Transitivity, Coreness)...
# --- Metrics Calculation Complete ---
#
# =============== Analysis Report: anime_jacth005_2010_pkl ===============
# Metric                                   | Value        | Description
# -----------------------------------------------------------------------------------------------
# Number of nodes                          | 2952         | Total anime titles
# Number of edges                          | 276701       | Total connections (shared audience)
# Average degree (weighted)                | 16.2664      | Avg connectivity (popularity)
# Degree std (weighted)                    | 22.6014      | Variance in popularity
# Connected components                     | 8            | Isolated groups
# LCC size                                 | 2937         | Size of main component
# Weighted diameter - longest shortest path (distance-based) | 182.9823     |
# Weighted radius (distance-based)         | N/A          | Min eccentricity in LCC
# Mean eccentricity (distance-based)       | N/A          | Avg max distance to others
# Avg path length (weighted LCC)           | 41.0852      | Avg steps to reach any anime
# Mean closeness (weighted distance)       | 0.0271       | Access speed to other nodes
# Mean betweenness (weighted distance)     | 0            | Bridge roles (connecting groups/clusters)
# Mean eigenvector (weighted strength)     | 0.1365       | Influence (connected to popular)
# Clustering coefficient mean (weighted)   | 0.5783       | Local cohesion (bubbles)
# Transitivity (weighted)                  | N/A          | Global triangle probability
# Core number mean                         | 119.1944     | Avg depth of embedding
# Max Core number                          | 374          | Deepest 'mainstream' core level
# Assortativity (degree)                   | 0.5101       | Link correlation (-1 to 1)
# Assortativity (strength/weighted)        | 0.3940       | Popularity correlation (-1 to 1)
# Graph Density                            | 0.0635       | Network saturation (0 to 1)
# ===============================================================================================
#
#
# >>> Processing 2011...
# Loading file with graph: 2011.pkl...
# Object is iGraph
# Edges: 335016. Weights (min/max): 0.0500 / 1.0000
#
# --- Starting Full Metrics Calculation for anime_jacth005_2011_pkl ---
#   ... Calculating Basic Metrics (Nodes, Edges, Degree)...
#   ... Calculating Path Metrics (Skipping slow ones)...
#       > Diameter (Longest shortest path)...
#       > Average Path Length...
#   ... Calculating Centrality Metrics (Closeness, Betweenness, Eigenvector)...
#       > Closeness Centrality...
#       > Betweenness Centrality (this may take time)...
#       > Eigenvector Centrality...
#   ... Calculating Structural Metrics (Clustering, Transitivity, Coreness)...
# --- Metrics Calculation Complete ---
#
# =============== Analysis Report: anime_jacth005_2011_pkl ===============
# Metric                                   | Value        | Description
# -----------------------------------------------------------------------------------------------
# Number of nodes                          | 3321         | Total anime titles
# Number of edges                          | 335016       | Total connections (shared audience)
# Average degree (weighted)                | 17.6801      | Avg connectivity (popularity)
# Degree std (weighted)                    | 24.4221      | Variance in popularity
# Connected components                     | 7            | Isolated groups
# LCC size                                 | 3308         | Size of main component
# Weighted diameter - longest shortest path (distance-based) | 141.8539     |
# Weighted radius (distance-based)         | N/A          | Min eccentricity in LCC
# Mean eccentricity (distance-based)       | N/A          | Avg max distance to others
# Avg path length (weighted LCC)           | 41.2792      | Avg steps to reach any anime
# Mean closeness (weighted distance)       | 0.0265       | Access speed to other nodes
# Mean betweenness (weighted distance)     | 0            | Bridge roles (connecting groups/clusters)
# Mean eigenvector (weighted strength)     | 0.1335       | Influence (connected to popular)
# Clustering coefficient mean (weighted)   | 0.5973       | Local cohesion (bubbles)
# Transitivity (weighted)                  | N/A          | Global triangle probability
# Core number mean                         | 128.4481     | Avg depth of embedding
# Max Core number                          | 405          | Deepest 'mainstream' core level
# Assortativity (degree)                   | 0.5165       | Link correlation (-1 to 1)
# Assortativity (strength/weighted)        | 0.3931       | Popularity correlation (-1 to 1)
# Graph Density                            | 0.0608       | Network saturation (0 to 1)
# ===============================================================================================
#
#
# >>> Processing 2012...
# Loading file with graph: 2012.pkl...
# Object is iGraph
# Edges: 381082. Weights (min/max): 0.0500 / 1.0000
#
# --- Starting Full Metrics Calculation for anime_jacth005_2012_pkl ---
#   ... Calculating Basic Metrics (Nodes, Edges, Degree)...
#   ... Calculating Path Metrics (Skipping slow ones)...
#       > Diameter (Longest shortest path)...
#       > Average Path Length...
#   ... Calculating Centrality Metrics (Closeness, Betweenness, Eigenvector)...
#       > Closeness Centrality...
#       > Betweenness Centrality (this may take time)...
#       > Eigenvector Centrality...
#   ... Calculating Structural Metrics (Clustering, Transitivity, Coreness)...
# --- Metrics Calculation Complete ---
#
# =============== Analysis Report: anime_jacth005_2012_pkl ===============
# Metric                                   | Value        | Description
# -----------------------------------------------------------------------------------------------
# Number of nodes                          | 3675         | Total anime titles
# Number of edges                          | 381082       | Total connections (shared audience)
# Average degree (weighted)                | 18.1284      | Avg connectivity (popularity)
# Degree std (weighted)                    | 25.6782      | Variance in popularity
# Connected components                     | 17           | Isolated groups
# LCC size                                 | 3634         | Size of main component
# Weighted diameter - longest shortest path (distance-based) | 160.3465     |
# Weighted radius (distance-based)         | N/A          | Min eccentricity in LCC
# Mean eccentricity (distance-based)       | N/A          | Avg max distance to others
# Avg path length (weighted LCC)           | 42.3176      | Avg steps to reach any anime
# Mean closeness (weighted distance)       | 0.0276       | Access speed to other nodes
# Mean betweenness (weighted distance)     | 0            | Bridge roles (connecting groups/clusters)
# Mean eigenvector (weighted strength)     | 0.1285       | Influence (connected to popular)
# Clustering coefficient mean (weighted)   | 0.5927       | Local cohesion (bubbles)
# Transitivity (weighted)                  | N/A          | Global triangle probability
# Core number mean                         | 130.3521     | Avg depth of embedding
# Max Core number                          | 418          | Deepest 'mainstream' core level
# Assortativity (degree)                   | 0.5036       | Link correlation (-1 to 1)
# Assortativity (strength/weighted)        | 0.3856       | Popularity correlation (-1 to 1)
# Graph Density                            | 0.0564       | Network saturation (0 to 1)
# ===============================================================================================
#
#
# >>> Processing 2013...
# Loading file with graph: 2013.pkl...
# Object is iGraph
# Edges: 436263. Weights (min/max): 0.0500 / 1.0000
#
# --- Starting Full Metrics Calculation for anime_jacth005_2013_pkl ---
#   ... Calculating Basic Metrics (Nodes, Edges, Degree)...
#   ... Calculating Path Metrics (Skipping slow ones)...
#       > Diameter (Longest shortest path)...
#       > Average Path Length...
#   ... Calculating Centrality Metrics (Closeness, Betweenness, Eigenvector)...
#       > Closeness Centrality...
#       > Betweenness Centrality (this may take time)...
#       > Eigenvector Centrality...
#   ... Calculating Structural Metrics (Clustering, Transitivity, Coreness)...
# --- Metrics Calculation Complete ---
#
# =============== Analysis Report: anime_jacth005_2013_pkl ===============
# Metric                                   | Value        | Description
# -----------------------------------------------------------------------------------------------
# Number of nodes                          | 4004         | Total anime titles
# Number of edges                          | 436263       | Total connections (shared audience)
# Average degree (weighted)                | 19.0008      | Avg connectivity (popularity)
# Degree std (weighted)                    | 27.1534      | Variance in popularity
# Connected components                     | 13           | Isolated groups
# LCC size                                 | 3979         | Size of main component
# Weighted diameter - longest shortest path (distance-based) | 203.0248     |
# Weighted radius (distance-based)         | N/A          | Min eccentricity in LCC
# Mean eccentricity (distance-based)       | N/A          | Avg max distance to others
# Avg path length (weighted LCC)           | 42.9638      | Avg steps to reach any anime
# Mean closeness (weighted distance)       | 0.0253       | Access speed to other nodes
# Mean betweenness (weighted distance)     | 0            | Bridge roles (connecting groups/clusters)
# Mean eigenvector (weighted strength)     | 0.1227       | Influence (connected to popular)
# Clustering coefficient mean (weighted)   | 0.5950       | Local cohesion (bubbles)
# Transitivity (weighted)                  | N/A          | Global triangle probability
# Core number mean                         | 133.9875     | Avg depth of embedding
# Max Core number                          | 425          | Deepest 'mainstream' core level
# Assortativity (degree)                   | 0.4998       | Link correlation (-1 to 1)
# Assortativity (strength/weighted)        | 0.3884       | Popularity correlation (-1 to 1)
# Graph Density                            | 0.0544       | Network saturation (0 to 1)
# ===============================================================================================
#
#
# >>> Processing 2014...
# Loading file with graph: 2014.pkl...
# Object is iGraph
# Edges: 504452. Weights (min/max): 0.0500 / 1.0000
#
# --- Starting Full Metrics Calculation for anime_jacth005_2014_pkl ---
#   ... Calculating Basic Metrics (Nodes, Edges, Degree)...
#   ... Calculating Path Metrics (Skipping slow ones)...
#       > Diameter (Longest shortest path)...
#       > Average Path Length...
#   ... Calculating Centrality Metrics (Closeness, Betweenness, Eigenvector)...
#       > Closeness Centrality...
#       > Betweenness Centrality (this may take time)...
#       > Eigenvector Centrality...
#   ... Calculating Structural Metrics (Clustering, Transitivity, Coreness)...
# --- Metrics Calculation Complete ---
#
# =============== Analysis Report: anime_jacth005_2014_pkl ===============
# Metric                                   | Value        | Description
# -----------------------------------------------------------------------------------------------
# Number of nodes                          | 4403         | Total anime titles
# Number of edges                          | 504452       | Total connections (shared audience)
# Average degree (weighted)                | 19.9852      | Avg connectivity (popularity)
# Degree std (weighted)                    | 28.9185      | Variance in popularity
# Connected components                     | 15           | Isolated groups
# LCC size                                 | 4373         | Size of main component
# Weighted diameter - longest shortest path (distance-based) | 188.0714     |
# Weighted radius (distance-based)         | N/A          | Min eccentricity in LCC
# Mean eccentricity (distance-based)       | N/A          | Avg max distance to others
# Avg path length (weighted LCC)           | 43.7089      | Avg steps to reach any anime
# Mean closeness (weighted distance)       | 0.0261       | Access speed to other nodes
# Mean betweenness (weighted distance)     | 0            | Bridge roles (connecting groups/clusters)
# Mean eigenvector (weighted strength)     | 0.1183       | Influence (connected to popular)
# Clustering coefficient mean (weighted)   | 0.5954       | Local cohesion (bubbles)
# Transitivity (weighted)                  | N/A          | Global triangle probability
# Core number mean                         | 138.9777     | Avg depth of embedding
# Max Core number                          | 439          | Deepest 'mainstream' core level
# Assortativity (degree)                   | 0.4900       | Link correlation (-1 to 1)
# Assortativity (strength/weighted)        | 0.3812       | Popularity correlation (-1 to 1)
# Graph Density                            | 0.0521       | Network saturation (0 to 1)
# ===============================================================================================
#
#
# >>> Processing 2015...
# Loading file with graph: 2015.pkl...
# Object is iGraph
# Edges: 583309. Weights (min/max): 0.0500 / 1.0000
#
# --- Starting Full Metrics Calculation for anime_jacth005_2015_pkl ---
#   ... Calculating Basic Metrics (Nodes, Edges, Degree)...
#   ... Calculating Path Metrics (Skipping slow ones)...
#       > Diameter (Longest shortest path)...
#       > Average Path Length...
#   ... Calculating Centrality Metrics (Closeness, Betweenness, Eigenvector)...
#       > Closeness Centrality...
#       > Betweenness Centrality (this may take time)...
#       > Eigenvector Centrality...
#   ... Calculating Structural Metrics (Clustering, Transitivity, Coreness)...
# --- Metrics Calculation Complete ---
#
# =============== Analysis Report: anime_jacth005_2015_pkl ===============
# Metric                                   | Value        | Description
# -----------------------------------------------------------------------------------------------
# Number of nodes                          | 4918         | Total anime titles
# Number of edges                          | 583309       | Total connections (shared audience)
# Average degree (weighted)                | 20.8393      | Avg connectivity (popularity)
# Degree std (weighted)                    | 30.7893      | Variance in popularity
# Connected components                     | 20           | Isolated groups
# LCC size                                 | 4880         | Size of main component
# Weighted diameter - longest shortest path (distance-based) | 193.2822     |
# Weighted radius (distance-based)         | N/A          | Min eccentricity in LCC
# Mean eccentricity (distance-based)       | N/A          | Avg max distance to others
# Avg path length (weighted LCC)           | 44.2204      | Avg steps to reach any anime
# Mean closeness (weighted distance)       | 0.0259       | Access speed to other nodes
# Mean betweenness (weighted distance)     | 0            | Bridge roles (connecting groups/clusters)
# Mean eigenvector (weighted strength)     | 0.1134       | Influence (connected to popular)
# Clustering coefficient mean (weighted)   | 0.5968       | Local cohesion (bubbles)
# Transitivity (weighted)                  | N/A          | Global triangle probability
# Core number mean                         | 142.8729     | Avg depth of embedding
# Max Core number                          | 462          | Deepest 'mainstream' core level
# Assortativity (degree)                   | 0.4990       | Link correlation (-1 to 1)
# Assortativity (strength/weighted)        | 0.3877       | Popularity correlation (-1 to 1)
# Graph Density                            | 0.0482       | Network saturation (0 to 1)
# ===============================================================================================
#
#
# >>> Processing 2016...
# Loading file with graph: 2016.pkl...
# Object is iGraph
# Edges: 674276. Weights (min/max): 0.0500 / 1.0000
#
# --- Starting Full Metrics Calculation for anime_jacth005_2016_pkl ---
#   ... Calculating Basic Metrics (Nodes, Edges, Degree)...
#   ... Calculating Path Metrics (Skipping slow ones)...
#       > Diameter (Longest shortest path)...
#       > Average Path Length...
#   ... Calculating Centrality Metrics (Closeness, Betweenness, Eigenvector)...
#       > Closeness Centrality...
#       > Betweenness Centrality (this may take time)...
#       > Eigenvector Centrality...
#   ... Calculating Structural Metrics (Clustering, Transitivity, Coreness)...
# --- Metrics Calculation Complete ---
#
# =============== Analysis Report: anime_jacth005_2016_pkl ===============
# Metric                                   | Value        | Description
# -----------------------------------------------------------------------------------------------
# Number of nodes                          | 5442         | Total anime titles
# Number of edges                          | 674276       | Total connections (shared audience)
# Average degree (weighted)                | 21.8342      | Avg connectivity (popularity)
# Degree std (weighted)                    | 32.9348      | Variance in popularity
# Connected components                     | 16           | Isolated groups
# LCC size                                 | 5408         | Size of main component
# Weighted diameter - longest shortest path (distance-based) | 167.0481     |
# Weighted radius (distance-based)         | N/A          | Min eccentricity in LCC
# Mean eccentricity (distance-based)       | N/A          | Avg max distance to others
# Avg path length (weighted LCC)           | 44.7794      | Avg steps to reach any anime
# Mean closeness (weighted distance)       | 0.0250       | Access speed to other nodes
# Mean betweenness (weighted distance)     | 0            | Bridge roles (connecting groups/clusters)
# Mean eigenvector (weighted strength)     | 0.1103       | Influence (connected to popular)
# Clustering coefficient mean (weighted)   | 0.5952       | Local cohesion (bubbles)
# Transitivity (weighted)                  | N/A          | Global triangle probability
# Core number mean                         | 149.6839     | Avg depth of embedding
# Max Core number                          | 499          | Deepest 'mainstream' core level
# Assortativity (degree)                   | 0.5029       | Link correlation (-1 to 1)
# Assortativity (strength/weighted)        | 0.3869       | Popularity correlation (-1 to 1)
# Graph Density                            | 0.0455       | Network saturation (0 to 1)
# ===============================================================================================
#
#
# >>> Processing 2017...
# Loading file with graph: 2017.pkl...
# Object is iGraph
# Edges: 772046. Weights (min/max): 0.0500 / 1.0000
#
# --- Starting Full Metrics Calculation for anime_jacth005_2017_pkl ---
#   ... Calculating Basic Metrics (Nodes, Edges, Degree)...
#   ... Calculating Path Metrics (Skipping slow ones)...
#       > Diameter (Longest shortest path)...
#       > Average Path Length...
#   ... Calculating Centrality Metrics (Closeness, Betweenness, Eigenvector)...
#       > Closeness Centrality...
#       > Betweenness Centrality (this may take time)...
#       > Eigenvector Centrality...
#   ... Calculating Structural Metrics (Clustering, Transitivity, Coreness)...
# --- Metrics Calculation Complete ---
#
# =============== Analysis Report: anime_jacth005_2017_pkl ===============
# Metric                                   | Value        | Description
# -----------------------------------------------------------------------------------------------
# Number of nodes                          | 5957         | Total anime titles
# Number of edges                          | 772046       | Total connections (shared audience)
# Average degree (weighted)                | 22.9169      | Avg connectivity (popularity)
# Degree std (weighted)                    | 35.2510      | Variance in popularity
# Connected components                     | 15           | Isolated groups
# LCC size                                 | 5926         | Size of main component
# Weighted diameter - longest shortest path (distance-based) | 164.6109     |
# Weighted radius (distance-based)         | N/A          | Min eccentricity in LCC
# Mean eccentricity (distance-based)       | N/A          | Avg max distance to others
# Avg path length (weighted LCC)           | 44.9898      | Avg steps to reach any anime
# Mean closeness (weighted distance)       | 0.0248       | Access speed to other nodes
# Mean betweenness (weighted distance)     | 0            | Bridge roles (connecting groups/clusters)
# Mean eigenvector (weighted strength)     | 0.1050       | Influence (connected to popular)
# Clustering coefficient mean (weighted)   | 0.5887       | Local cohesion (bubbles)
# Transitivity (weighted)                  | N/A          | Global triangle probability
# Core number mean                         | 155.5726     | Avg depth of embedding
# Max Core number                          | 527          | Deepest 'mainstream' core level
# Assortativity (degree)                   | 0.5051       | Link correlation (-1 to 1)
# Assortativity (strength/weighted)        | 0.3835       | Popularity correlation (-1 to 1)
# Graph Density                            | 0.0435       | Network saturation (0 to 1)
# ===============================================================================================
#
#
# >>> Processing 2018...
# Loading file with graph: 2018.pkl...
# Object is iGraph
# Edges: 818665. Weights (min/max): 0.0500 / 1.0000
#
# --- Starting Full Metrics Calculation for anime_jacth005_2018_pkl ---
#   ... Calculating Basic Metrics (Nodes, Edges, Degree)...
#   ... Calculating Path Metrics (Skipping slow ones)...
#       > Diameter (Longest shortest path)...
#       > Average Path Length...
#   ... Calculating Centrality Metrics (Closeness, Betweenness, Eigenvector)...
#       > Closeness Centrality...
#       > Betweenness Centrality (this may take time)...
#       > Eigenvector Centrality...
#   ... Calculating Structural Metrics (Clustering, Transitivity, Coreness)...
# --- Metrics Calculation Complete ---
#
# =============== Analysis Report: anime_jacth005_2018_pkl ===============
# Metric                                   | Value        | Description
# -----------------------------------------------------------------------------------------------
# Number of nodes                          | 6129         | Total anime titles
# Number of edges                          | 818665       | Total connections (shared audience)
# Average degree (weighted)                | 23.6264      | Avg connectivity (popularity)
# Degree std (weighted)                    | 36.3400      | Variance in popularity
# Connected components                     | 11           | Isolated groups
# LCC size                                 | 6105         | Size of main component
# Weighted diameter - longest shortest path (distance-based) | 188.4689     |
# Weighted radius (distance-based)         | N/A          | Min eccentricity in LCC
# Mean eccentricity (distance-based)       | N/A          | Avg max distance to others
# Avg path length (weighted LCC)           | 44.3852      | Avg steps to reach any anime
# Mean closeness (weighted distance)       | 0.0250       | Access speed to other nodes
# Mean betweenness (weighted distance)     | 0            | Bridge roles (connecting groups/clusters)
# Mean eigenvector (weighted strength)     | 0.1042       | Influence (connected to popular)
# Clustering coefficient mean (weighted)   | 0.5875       | Local cohesion (bubbles)
# Transitivity (weighted)                  | N/A          | Global triangle probability
# Core number mean                         | 160.1605     | Avg depth of embedding
# Max Core number                          | 541          | Deepest 'mainstream' core level
# Assortativity (degree)                   | 0.5052       | Link correlation (-1 to 1)
# Assortativity (strength/weighted)        | 0.3816       | Popularity correlation (-1 to 1)
# Graph Density                            | 0.0436       | Network saturation (0 to 1)
# ===============================================================================================

# %% [markdown]
# # **3. User Graph Metrics Analysis (2006–2018)**
#
# In this section, we analyze the evolution of the User social graph.
#
# **Optimization Note:**
# Unlike the Anime graph, the User graph is significantly larger and denser. To ensure calculations complete in a reasonable time, we have **disabled path-based metrics** (Betweenness Centrality, Closeness Centrality, Diameter, Radius, and Average Path Length). These metrics require traversing every possible path between nodes, which is computationally infeasible for large social networks in this context.
#
# **Active Metrics for Users:**
#
# **Network Scale**
# * **Active Users (Nodes):** Total count of unique users participating in the network.
# * **Interactions (Edges):** Total number of connections (friendships or shared interactions) between users.
# * **Density:** The ratio of actual social connections to potential ones (network saturation).
#
# **Social Structure & Fragmentation**
# * **Connected Components:** The number of isolated user groups.
# * **LCC Size:** The size of the Largest Connected Component (the main "giant" community).
#
# **Social Cohesion (Clustering)**
# * **Global Transitivity:** The probability that two of a user's friends are also friends with each other (global triangle ratio).
# * **Avg Clustering Coefficient:** The average local "clique-ness" of user circles.
#
# **Hierarchy & Homophily**
# * **Avg Degree & Std:** The average number of friends per user and the inequality of popularity.
# * **Core Number (Mean & Max):** A measure of how deep users are embedded in the social web (identifying the "inner circle").
# * **Assortativity:** The correlation between linked users (do popular users tend to connect with other popular users?).

# %%
print("--- Starting Manual Analysis for User Graphs (2006-2018) ---\n")

# 2006
print(">>> Processing Users 2006...")
GraphActionsIG.print_user_graph_metrics(
    GraphActionsIG.get_user_metrics_light(
        GraphActionsIG.get_graph(user_raw_2006_pkl), 
        "user_2006"
    ), "user_2006"
)

# 2007
print(">>> Processing Users 2007...")
GraphActionsIG.print_user_graph_metrics(
    GraphActionsIG.get_user_metrics_light(
        GraphActionsIG.get_graph(user_raw_2007_pkl), 
        "user_2007"
    ), "user_2007"
)

# 2008
print(">>> Processing Users 2008...")
GraphActionsIG.print_user_graph_metrics(
    GraphActionsIG.get_user_metrics_light(
        GraphActionsIG.get_graph(user_raw_2008_pkl), 
        "user_2008"
    ), "user_2008"
)

# 2009
print(">>> Processing Users 2009...")
GraphActionsIG.print_user_graph_metrics(
    GraphActionsIG.get_user_metrics_light(
        GraphActionsIG.get_graph(user_raw_2009_pkl), 
        "user_2009"
    ), "user_2009"
)

# 2010
print(">>> Processing Users 2010...")
GraphActionsIG.print_user_graph_metrics(
    GraphActionsIG.get_user_metrics_light(
        GraphActionsIG.get_graph(user_raw_2010_pkl), 
        "user_2010"
    ), "user_2010"
)

# 2011
print(">>> Processing Users 2011...")
GraphActionsIG.print_user_graph_metrics(
    GraphActionsIG.get_user_metrics_light(
        GraphActionsIG.get_graph(user_raw_2011_pkl), 
        "user_2011"
    ), "user_2011"
)

# 2012
print(">>> Processing Users 2012...")
GraphActionsIG.print_user_graph_metrics(
    GraphActionsIG.get_user_metrics_light(
        GraphActionsIG.get_graph(user_raw_2012_pkl), 
        "user_2012"
    ), "user_2012"
)

# 2013
print(">>> Processing Users 2013...")
GraphActionsIG.print_user_graph_metrics(
    GraphActionsIG.get_user_metrics_light(
        GraphActionsIG.get_graph(user_raw_2013_pkl), 
        "user_2013"
    ), "user_2013"
)

# 2014
print(">>> Processing Users 2014...")
GraphActionsIG.print_user_graph_metrics(
    GraphActionsIG.get_user_metrics_light(
        GraphActionsIG.get_graph(user_raw_2014_pkl), 
        "user_2014"
    ), "user_2014"
)

# 2015
print(">>> Processing Users 2015...")
GraphActionsIG.print_user_graph_metrics(
    GraphActionsIG.get_user_metrics_light(
        GraphActionsIG.get_graph(user_raw_2015_pkl), 
        "user_2015"
    ), "user_2015"
)

# 2016
print(">>> Processing Users 2016...")
GraphActionsIG.print_user_graph_metrics(
    GraphActionsIG.get_user_metrics_light(
        GraphActionsIG.get_graph(user_raw_2016_pkl), 
        "user_2016"
    ), "user_2016"
)

# 2017
print(">>> Processing Users 2017...")
GraphActionsIG.print_user_graph_metrics(
    GraphActionsIG.get_user_metrics_light(
        GraphActionsIG.get_graph(user_raw_2017_pkl), 
        "user_2017"
    ), "user_2017"
)

# 2018
print(">>> Processing Users 2018...")
GraphActionsIG.print_user_graph_metrics(
    GraphActionsIG.get_user_metrics_light(
        GraphActionsIG.get_graph(user_raw_2018_pkl), 
        "user_2018"
    ), "user_2018"
)
# Out:
# --- Starting Manual Analysis for User Graphs (2006-2018) ---
#
# >>> Processing Users 2006...
# Loading file with graph: user_graph_2006_thr_3_q_low5_cut_1900.gpickle...
# Object is iGraph
# Edges: 2123. Weights (min/max): 4.0000 / 29.0000
# ============================ User Analysis: user_2006 ===========================
# Metric                              | Value      | Description
# --------------------------------------------------------------------------------
# Total Active Users                  | 308        | Unique users in the network
# Total Interactions                  | 2123       | Votes for the same anime between users
# Network Density                     | 0.0449     | Saturation (How connected is the community?)
# Avg Connections                     | 13.7857    | Avg number of friends per user
# Connection Variance                 | 19.3880    | Inequality in popularity
# Isolated Groups                     | 1          | Fragmented sub-communities
# LCC Size                            | 308        | Users in the main 'giant' community
# Global Transitivity                 | 0.3197     | Probability of triangles (tight circles)
# Avg Clustering Coeff                | 0.6338     | Local social cohesion (cliques)
# Avg Core Depth                      | 7.6688     | Avg embedding in the social web
# Max Core Level                      | 19         | Deepest/Most central social tier
# Homophily (Assortativity)           | -0.2250    | Do popular users link to popular users?
# ================================================================================
#
# >>> Processing Users 2007...
# Loading file with graph: user_graph_2007_thr_3_q_low5_cut_1900.gpickle...
# Object is iGraph
# Edges: 77089. Weights (min/max): 4.0000 / 68.0000
# ============================ User Analysis: user_2007 ===========================
# Metric                              | Value      | Description
# --------------------------------------------------------------------------------
# Total Active Users                  | 1816       | Unique users in the network
# Total Interactions                  | 77089      | Votes for the same anime between users
# Network Density                     | 0.0468     | Saturation (How connected is the community?)
# Avg Connections                     | 84.8998    | Avg number of friends per user
# Connection Variance                 | 128.0889   | Inequality in popularity
# Isolated Groups                     | 1          | Fragmented sub-communities
# LCC Size                            | 1816       | Users in the main 'giant' community
# Global Transitivity                 | 0.3389     | Probability of triangles (tight circles)
# Avg Clustering Coeff                | 0.7463     | Local social cohesion (cliques)
# Avg Core Depth                      | 46.8524    | Avg embedding in the social web
# Max Core Level                      | 114        | Deepest/Most central social tier
# Homophily (Assortativity)           | -0.2889    | Do popular users link to popular users?
# ================================================================================
#
# >>> Processing Users 2008...
# Loading file with graph: user_graph_2008_thr_3_q_low5_cut_1900.gpickle...
# Object is iGraph
# Edges: 730031. Weights (min/max): 4.0000 / 91.0000
# ============================ User Analysis: user_2008 ===========================
# Metric                              | Value      | Description
# --------------------------------------------------------------------------------
# Total Active Users                  | 6512       | Unique users in the network
# Total Interactions                  | 730031     | Votes for the same anime between users
# Network Density                     | 0.0344     | Saturation (How connected is the community?)
# Avg Connections                     | 224.2110   | Avg number of friends per user
# Connection Variance                 | 355.8884   | Inequality in popularity
# Isolated Groups                     | 1          | Fragmented sub-communities
# LCC Size                            | 6512       | Users in the main 'giant' community
# Global Transitivity                 | 0.3270     | Probability of triangles (tight circles)
# Avg Clustering Coeff                | 0.7363     | Local social cohesion (cliques)
# Avg Core Depth                      | 122.0774   | Avg embedding in the social web
# Max Core Level                      | 326        | Deepest/Most central social tier
# Homophily (Assortativity)           | -0.2416    | Do popular users link to popular users?
# ================================================================================
#
# >>> Processing Users 2009...
# Loading file with graph: user_graph_2009_thr_3_q_low5_cut_1900.gpickle...
# Object is iGraph
# Edges: 2270878. Weights (min/max): 4.0000 / 119.0000
# ============================ User Analysis: user_2009 ===========================
# Metric                              | Value      | Description
# --------------------------------------------------------------------------------
# Total Active Users                  | 12193      | Unique users in the network
# Total Interactions                  | 2270878    | Votes for the same anime between users
# Network Density                     | 0.0306     | Saturation (How connected is the community?)
# Avg Connections                     | 372.4888   | Avg number of friends per user
# Connection Variance                 | 604.3212   | Inequality in popularity
# Isolated Groups                     | 2          | Fragmented sub-communities
# LCC Size                            | 12191      | Users in the main 'giant' community
# Global Transitivity                 | 0.3201     | Probability of triangles (tight circles)
# Avg Clustering Coeff                | 0.7376     | Local social cohesion (cliques)
# Avg Core Depth                      | 202.0222   | Avg embedding in the social web
# Max Core Level                      | 558        | Deepest/Most central social tier
# Homophily (Assortativity)           | -0.2272    | Do popular users link to popular users?
# ================================================================================
#
# >>> Processing Users 2010...
# Loading file with graph: user_graph_2010_thr_3_q_low5_cut_1900.gpickle...
# Object is iGraph
# Edges: 3976465. Weights (min/max): 4.0000 / 119.0000
# ============================ User Analysis: user_2010 ===========================
# Metric                              | Value      | Description
# --------------------------------------------------------------------------------
# Total Active Users                  | 16749      | Unique users in the network
# Total Interactions                  | 3976465    | Votes for the same anime between users
# Network Density                     | 0.0284     | Saturation (How connected is the community?)
# Avg Connections                     | 474.8301   | Avg number of friends per user
# Connection Variance                 | 772.1128   | Inequality in popularity
# Isolated Groups                     | 1          | Fragmented sub-communities
# LCC Size                            | 16749      | Users in the main 'giant' community
# Global Transitivity                 | 0.3156     | Probability of triangles (tight circles)
# Avg Clustering Coeff                | 0.7316     | Local social cohesion (cliques)
# Avg Core Depth                      | 256.9335   | Avg embedding in the social web
# Max Core Level                      | 721        | Deepest/Most central social tier
# Homophily (Assortativity)           | -0.2110    | Do popular users link to popular users?
# ================================================================================
#
# >>> Processing Users 2011...
# Loading file with graph: user_graph_2011_thr_3_q_low5_cut_1900.gpickle...
# Object is iGraph
# Edges: 5522053. Weights (min/max): 4.0000 / 119.0000
# ============================ User Analysis: user_2011 ===========================
# Metric                              | Value      | Description
# --------------------------------------------------------------------------------
# Total Active Users                  | 20442      | Unique users in the network
# Total Interactions                  | 5522053    | Votes for the same anime between users
# Network Density                     | 0.0264     | Saturation (How connected is the community?)
# Avg Connections                     | 540.2654   | Avg number of friends per user
# Connection Variance                 | 880.9086   | Inequality in popularity
# Isolated Groups                     | 1          | Fragmented sub-communities
# LCC Size                            | 20442      | Users in the main 'giant' community
# Global Transitivity                 | 0.3104     | Probability of triangles (tight circles)
# Avg Clustering Coeff                | 0.7219     | Local social cohesion (cliques)
# Avg Core Depth                      | 291.5720   | Avg embedding in the social web
# Max Core Level                      | 828        | Deepest/Most central social tier
# Homophily (Assortativity)           | -0.1972    | Do popular users link to popular users?
# ================================================================================
#
# >>> Processing Users 2012...
# Loading file with graph: user_graph_2012_thr_3_q_low5_cut_1900.gpickle...
# Object is iGraph
# Edges: 7101572. Weights (min/max): 4.0000 / 130.0000
# ============================ User Analysis: user_2012 ===========================
# Metric                              | Value      | Description
# --------------------------------------------------------------------------------
# Total Active Users                  | 24472      | Unique users in the network
# Total Interactions                  | 7101572    | Votes for the same anime between users
# Network Density                     | 0.0237     | Saturation (How connected is the community?)
# Avg Connections                     | 580.3835   | Avg number of friends per user
# Connection Variance                 | 957.7022   | Inequality in popularity
# Isolated Groups                     | 3          | Fragmented sub-communities
# LCC Size                            | 24468      | Users in the main 'giant' community
# Global Transitivity                 | 0.3036     | Probability of triangles (tight circles)
# Avg Clustering Coeff                | 0.7116     | Local social cohesion (cliques)
# Avg Core Depth                      | 312.1279   | Avg embedding in the social web
# Max Core Level                      | 904        | Deepest/Most central social tier
# Homophily (Assortativity)           | -0.1818    | Do popular users link to popular users?
# ================================================================================
#
# >>> Processing Users 2013...
# Loading file with graph: user_graph_2013_thr_3_q_low5_cut_1900.gpickle...
# Object is iGraph
# Edges: 8768940. Weights (min/max): 4.0000 / 130.0000
# ============================ User Analysis: user_2013 ===========================
# Metric                              | Value      | Description
# --------------------------------------------------------------------------------
# Total Active Users                  | 28452      | Unique users in the network
# Total Interactions                  | 8768940    | Votes for the same anime between users
# Network Density                     | 0.0217     | Saturation (How connected is the community?)
# Avg Connections                     | 616.4024   | Avg number of friends per user
# Connection Variance                 | 1020.5307  | Inequality in popularity
# Isolated Groups                     | 4          | Fragmented sub-communities
# LCC Size                            | 28446      | Users in the main 'giant' community
# Global Transitivity                 | 0.2980     | Probability of triangles (tight circles)
# Avg Clustering Coeff                | 0.7005     | Local social cohesion (cliques)
# Avg Core Depth                      | 330.5989   | Avg embedding in the social web
# Max Core Level                      | 966        | Deepest/Most central social tier
# Homophily (Assortativity)           | -0.1659    | Do popular users link to popular users?
# ================================================================================
#
# >>> Processing Users 2014...
# Loading file with graph: user_graph_2014_thr_3_q_low5_cut_1900.gpickle...
# Object is iGraph
# Edges: 10456588. Weights (min/max): 4.0000 / 154.0000
# ============================ User Analysis: user_2014 ===========================
# Metric                              | Value      | Description
# --------------------------------------------------------------------------------
# Total Active Users                  | 32377      | Unique users in the network
# Total Interactions                  | 10456588   | Votes for the same anime between users
# Network Density                     | 0.0200     | Saturation (How connected is the community?)
# Avg Connections                     | 645.9269   | Avg number of friends per user
# Connection Variance                 | 1065.9327  | Inequality in popularity
# Isolated Groups                     | 3          | Fragmented sub-communities
# LCC Size                            | 32373      | Users in the main 'giant' community
# Global Transitivity                 | 0.2930     | Probability of triangles (tight circles)
# Avg Clustering Coeff                | 0.6868     | Local social cohesion (cliques)
# Avg Core Depth                      | 345.3205   | Avg embedding in the social web
# Max Core Level                      | 1011       | Deepest/Most central social tier
# Homophily (Assortativity)           | -0.1477    | Do popular users link to popular users?
# ================================================================================
#
# >>> Processing Users 2015...
# Loading file with graph: user_graph_2015_thr_3_q_low5_cut_1900.gpickle...
# Object is iGraph
# Edges: 12481226. Weights (min/max): 4.0000 / 173.0000
# ============================ User Analysis: user_2015 ===========================
# Metric                              | Value      | Description
# --------------------------------------------------------------------------------
# Total Active Users                  | 36435      | Unique users in the network
# Total Interactions                  | 12481226   | Votes for the same anime between users
# Network Density                     | 0.0188     | Saturation (How connected is the community?)
# Avg Connections                     | 685.1229   | Avg number of friends per user
# Connection Variance                 | 1113.3870  | Inequality in popularity
# Isolated Groups                     | 4          | Fragmented sub-communities
# LCC Size                            | 36429      | Users in the main 'giant' community
# Global Transitivity                 | 0.2874     | Probability of triangles (tight circles)
# Avg Clustering Coeff                | 0.6774     | Local social cohesion (cliques)
# Avg Core Depth                      | 364.6363   | Avg embedding in the social web
# Max Core Level                      | 1050       | Deepest/Most central social tier
# Homophily (Assortativity)           | -0.1330    | Do popular users link to popular users?
# ================================================================================
#
# >>> Processing Users 2016...
# Loading file with graph: user_graph_2016_thr_3_q_low5_cut_1900.gpickle...
# Object is iGraph
# Edges: 15427273. Weights (min/max): 4.0000 / 196.0000
# ============================ User Analysis: user_2016 ===========================
# Metric                              | Value      | Description
# --------------------------------------------------------------------------------
# Total Active Users                  | 40780      | Unique users in the network
# Total Interactions                  | 15427273   | Votes for the same anime between users
# Network Density                     | 0.0186     | Saturation (How connected is the community?)
# Avg Connections                     | 756.6098   | Avg number of friends per user
# Connection Variance                 | 1186.8483  | Inequality in popularity
# Isolated Groups                     | 3          | Fragmented sub-communities
# LCC Size                            | 40776      | Users in the main 'giant' community
# Global Transitivity                 | 0.2815     | Probability of triangles (tight circles)
# Avg Clustering Coeff                | 0.6673     | Local social cohesion (cliques)
# Avg Core Depth                      | 400.1986   | Avg embedding in the social web
# Max Core Level                      | 1088       | Deepest/Most central social tier
# Homophily (Assortativity)           | -0.1313    | Do popular users link to popular users?
# ================================================================================
#
# >>> Processing Users 2017...
# Loading file with graph: user_graph_2017_thr_3_q_low5_cut_1900.gpickle...
# Object is iGraph
# Edges: 19544972. Weights (min/max): 4.0000 / 234.0000
# ============================ User Analysis: user_2017 ===========================
# Metric                              | Value      | Description
# --------------------------------------------------------------------------------
# Total Active Users                  | 44632      | Unique users in the network
# Total Interactions                  | 19544972   | Votes for the same anime between users
# Network Density                     | 0.0196     | Saturation (How connected is the community?)
# Avg Connections                     | 875.8277   | Avg number of friends per user
# Connection Variance                 | 1318.9774  | Inequality in popularity
# Isolated Groups                     | 3          | Fragmented sub-communities
# LCC Size                            | 44628      | Users in the main 'giant' community
# Global Transitivity                 | 0.2783     | Probability of triangles (tight circles)
# Avg Clustering Coeff                | 0.6633     | Local social cohesion (cliques)
# Avg Core Depth                      | 459.6731   | Avg embedding in the social web
# Max Core Level                      | 1132       | Deepest/Most central social tier
# Homophily (Assortativity)           | -0.1510    | Do popular users link to popular users?
# ================================================================================
#
# >>> Processing Users 2018...
# Loading file with graph: user_graph_2018_thr_3_q_low5_cut_1900.gpickle...
# Object is iGraph
# Edges: 22467045. Weights (min/max): 4.0000 / 236.0000
# ============================ User Analysis: user_2018 ===========================
# Metric                              | Value      | Description
# --------------------------------------------------------------------------------
# Total Active Users                  | 46374      | Unique users in the network
# Total Interactions                  | 22467045   | Votes for the same anime between users
# Network Density                     | 0.0209     | Saturation (How connected is the community?)
# Avg Connections                     | 968.9501   | Avg number of friends per user
# Connection Variance                 | 1430.9444  | Inequality in popularity
# Isolated Groups                     | 3          | Fragmented sub-communities
# LCC Size                            | 46370      | Users in the main 'giant' community
# Global Transitivity                 | 0.2809     | Probability of triangles (tight circles)
# Avg Clustering Coeff                | 0.6644     | Local social cohesion (cliques)
# Avg Core Depth                      | 520.3112   | Avg embedding in the social web
# Max Core Level                      | 1288       | Deepest/Most central social tier
# Homophily (Assortativity)           | -0.1625    | Do popular users link to popular users?
# ================================================================================
